# %%
# Importar libreria Geopandas
import geopandas as gpd
import urllib.request
import xml.etree.ElementTree as ET

# %%
url = "https://www.ideandalucia.es/services/DERA_g12_servicios/wfs?service=wfs&request=getcapabilities"

gdf = gpd.read_file(
    url, 
    layer='DERA_g12_servicios:g12_01_CentroSalud', 
    engine="pyogrio", 
    encoding="utf-8"
)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:1321, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1320 try:
# -> 1321     h.request(req.get_method(), req.selector, req.data, headers,
#    1322               encode_chunked=req.has_header('Transfer-encoding'))
#    1323 except OSError as err: # timeout error
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1358, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1357 """Send a complete request to the server."""
# -> 1358 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1404, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1403     body = _encode(body, 'body')
# -> 1404 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1353, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1352     raise CannotSendHeader()
# -> 1353 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1113, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1112 del self._buffer[:]
# -> 1113 self.send(msg)
#    1115 if message_body is not None:
#    1116
#    1117     # create a consistent interface to message_body
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1057, in HTTPConnection.send(self, data)
#    1056 if self.auto_open:
# -> 1057     self.connect()
#    1058 else:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1492, in HTTPSConnection.connect(self)
#    1490 "Connect to a host on a given (SSL) port."
# -> 1492 super().connect()
#    1494 if self._tunnel_host:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1023, in HTTPConnection.connect(self)
#    1022 sys.audit("http.client.connect", self, self.host, self.port)
# -> 1023 self.sock = self._create_connection(
#    1024     (self.host,self.port), self.timeout, self.source_address)
#    1025 # Might fail in OSs that don't implement TCP_NODELAY
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\socket.py:870, in create_connection(address, timeout, source_address, all_errors)
#     869 if not all_errors:
# --> 870     raise exceptions[0]
#     871 raise ExceptionGroup("create_connection failed", exceptions)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\socket.py:855, in create_connection(address, timeout, source_address, all_errors)
#     854     sock.bind(source_address)
# --> 855 sock.connect(sa)
#     856 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 url = "https://www.ideandalucia.es/services/DERA_g12_servicios/wfs?service=wfs&request=getcapabilities"
# ----> 3 gdf = gpd.read_file(
#       4     url,
#       5     layer='DERA_g12_servicios:g12_01_CentroSalud',
#       6     engine="pyogrio",
#       7     encoding="utf-8"
#       8 )
#
# File c:\Users\Usuario\Documents\GitHub\Andaluc-a-Quick-Data\.venv\Lib\site-packages\geopandas\io\file.py:300, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     294 if _is_url(filename):
#     295     # if it is a url that supports random access -> pass through to
#     296     # pyogrio/fiona as is (to support downloading only part of the file)
#     297     # otherwise still download manually because pyogrio/fiona don't support
#     298     # all types of urls (https://github.com/geopandas/geopandas/issues/2908)
#     299     try:
# --> 300         with urllib.request.urlopen(
#     301             Request(filename, headers={"Range": "bytes=0-1"})
#     302         ) as response:
#     303             if (
#     304                 response.headers.get("Accept-Ranges") == "none"
#     305                 or response.status != HTTPStatus.PARTIAL_CONTENT
#     306             ):
#     307                 from_bytes = True
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:187, in urlopen(url, data, timeout, context)
#     185 else:
#     186     opener = _opener
# --> 187 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:487, in OpenerDirector.open(self, fullurl, data, timeout)
#     484     req = meth(req)
#     486 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 487 response = self._open(req, data)
#     489 # post-process response
#     490 meth_name = protocol+"_response"
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:504, in OpenerDirector._open(self, req, data)
#     501     return result
#     503 protocol = req.type
# --> 504 result = self._call_chain(self.handle_open, protocol, protocol +
#     505                           '_open', req)
#     506 if result:
#     507     return result
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:464, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     462 for handler in handlers:
#     463     func = getattr(handler, meth_name)
# --> 464     result = func(*args)
#     465     if result is not None:
#     466         return result
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:1369, in HTTPSHandler.https_open(self, req)
#    1368 def https_open(self, req):
# -> 1369     return self.do_open(http.client.HTTPSConnection, req,
#    1370                         context=self._context)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:1324, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1321         h.request(req.get_method(), req.selector, req.data, headers,
#    1322                   encode_chunked=req.has_header('Transfer-encoding'))
#    1323     except OSError as err: # timeout error
# -> 1324         raise URLError(err)
#    1325     r = h.getresponse()
#    1326 except:
#
# URLError: <urlopen error [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder>

# %%
gdf
# Out:
#                                  gml_id         id_dera  \
# 0     g12_01_CentroSalud.11213100016586  11213100016586
# 1     g12_01_CentroSalud.11213100015684  11213100015684
# 2     g12_01_CentroSalud.11213100015588  11213100015588
# 3     g12_01_CentroSalud.11213100015997  11213100015997
# 4     g12_01_CentroSalud.11213100015615  11213100015615
# ...                                 ...             ...
# 1511  g12_01_CentroSalud.11213100015779  11213100015779
# 1512  g12_01_CentroSalud.11213100016177  11213100016177
# 1513  g12_01_CentroSalud.11213100016716  11213100016716
# 1514  g12_01_CentroSalud.11213100016744  11213100016744
# 1515  g12_01_CentroSalud.11213100015352  11213100015352
#
#                                 nombre  \
# 0                        Los Pascuales
# 1                           Benamaurel
# 2                        El Alcornocal
# 3                             El Molar
# 4                        Almayate Alto
# ...                                ...
# 1511                           Nechite
# 1512  San Sebastián de los Ballesteros
# 1513                          Zagrilla
# 1514                          Terreros
# 1515     Baena Dr. Ignacio Osuna Gómez
#
#                                       direccion   telefono  \
# 0               TRAVESIA AVENIDA PUERTA (LA), 0  953439008
# 1                 CALLE CALDERON DE LA BARCA, 0  958869608
# 2                CALLE CASTELAR (ALCORNOCAL), 5  600165925
# 3                    AVENIDA ANDALUCIA (DE), 12  953105134
# 4            CALLE FARMACEUTICO MORENO CHICA, 1  951289328
# ...                                         ...        ...
# 1511                     CALLE PLAZA (DE LA), 5  600160078
# 1512               CALLE NUEVAS POBLACIONES, 17  957307551
# 1513  PLAZA IGLESIA (DE LA) (ZAGRILLA ALTA), 10  957703753
# 1514                AVENIDA DEL MEDITERRANEO, 0  950474790
# 1515                   CALLE SALVADOR MUÑOZ, 20  957699529
#
#                                                     web  \
# 0     https://web.sas.junta-andalucia.es/servicioand...
# 1     https://web.sas.junta-andalucia.es/servicioand...
# 2     https://web.sas.junta-andalucia.es/servicioand...
# 3     https://web.sas.junta-andalucia.es/servicioand...
# 4     https://web.sas.junta-andalucia.es/servicioand...
# ...                                                 ...
# 1511  https://web.sas.junta-andalucia.es/servicioand...
# 1512  https://web.sas.junta-andalucia.es/servicioand...
# 1513  https://web.sas.junta-andalucia.es/servicioand...
# 1514  https://web.sas.junta-andalucia.es/servicioand...
# 1515  https://web.sas.junta-andalucia.es/servicioand...
#
#                              localidad cod_mun  \
# 0                        Los Pascuales   23072
# 1                           Benamaurel   18029
# 2                        El Alcornocal   14029
# 3                             El Molar   23028
# 4                        Almayate Bajo   29094
# ...                                ...     ...
# 1511                           Nechite   18183
# 1512  San Sebastián de los Ballesteros   14059
# 1513                     Zagrilla Alta   14055
# 1514              San Juan de Terreros   04075
# 1515                             Baena   14007
#
#                              municipio provincia  \
# 0                  La Puerta de Segura      Jaén
# 1                           Benamaurel   Granada
# 2                       Fuente Obejuna   Córdoba
# 3                              Cazorla      Jaén
# 4                         Vélez-Málaga    Málaga
# ...                                ...       ...
# 1511                             Válor   Granada
# 1512  San Sebastián de los Ballesteros   Córdoba
# 1513                 Priego de Córdoba   Córdoba
# 1514                             Pulpí   Almería
# 1515                             Baena   Córdoba
#
#                                    geometry
# 0     MULTIPOINT ((515555.677 4248392.575))
# 1     MULTIPOINT ((526681.975 4162248.628))
# 2     MULTIPOINT ((295900.925 4228500.376))
# 3       MULTIPOINT ((486809.08 4203642.59))
# 4      MULTIPOINT ((399131.892 4065564.99))
# ...                                     ...
# 1511  MULTIPOINT ((493637.813 4095204.083))
# 1512  MULTIPOINT ((339056.788 4168831.519))
# 1513  MULTIPOINT ((390125.307 4149608.512))
# 1514   MULTIPOINT ((618126.951 4135749.67))
# 1515  MULTIPOINT ((383391.944 4164377.662))
#
# [1516 rows x 11 columns]

# %%
# Borrrar columnas no necesarias
gdf = gdf.drop(columns=[ 'gml_id', 'id_dera', 'nombre', 'direccion', 'telefono', 'web', 'localidad', 'cod_mun',])

# %%
gdf
# Out:
#                              municipio provincia  \
# 0                  La Puerta de Segura      Jaén
# 1                           Benamaurel   Granada
# 2                       Fuente Obejuna   Córdoba
# 3                              Cazorla      Jaén
# 4                         Vélez-Málaga    Málaga
# ...                                ...       ...
# 1511                             Válor   Granada
# 1512  San Sebastián de los Ballesteros   Córdoba
# 1513                 Priego de Córdoba   Córdoba
# 1514                             Pulpí   Almería
# 1515                             Baena   Córdoba
#
#                                    geometry
# 0     MULTIPOINT ((515555.677 4248392.575))
# 1     MULTIPOINT ((526681.975 4162248.628))
# 2     MULTIPOINT ((295900.925 4228500.376))
# 3       MULTIPOINT ((486809.08 4203642.59))
# 4      MULTIPOINT ((399131.892 4065564.99))
# ...                                     ...
# 1511  MULTIPOINT ((493637.813 4095204.083))
# 1512  MULTIPOINT ((339056.788 4168831.519))
# 1513  MULTIPOINT ((390125.307 4149608.512))
# 1514   MULTIPOINT ((618126.951 4135749.67))
# 1515  MULTIPOINT ((383391.944 4164377.662))
#
# [1516 rows x 3 columns]

# %%
url = "https://www.ideandalucia.es/services/DERA_g12_servicios/wfs?service=wfs&request=getcapabilities"

gdf = gpd.read_file(
    url, 
    layer='DERA_g12_servicios:g12_02_Hospital_CAE', 
    engine="pyogrio", 
    encoding="utf-8"
)

# %%
gdf
# Out:
#                                  gml_id         id_dera  \
# 0    g12_02_Hospital_CAE.11213200015138  11213200015138
# 1    g12_02_Hospital_CAE.11213200015261  11213200015261
# 2    g12_02_Hospital_CAE.11213200015123  11213200015123
# 3    g12_02_Hospital_CAE.11213200015267  11213200015267
# 4    g12_02_Hospital_CAE.11213200015217  11213200015217
# ..                                  ...             ...
# 178  g12_02_Hospital_CAE.11213200015121  11213200015121
# 179  g12_02_Hospital_CAE.11213200015153  11213200015153
# 180  g12_02_Hospital_CAE.11213200015230  11213200015230
# 181  g12_02_Hospital_CAE.11213200015277  11213200015277
# 182  g12_02_Hospital_CAE.11213200015142  11213200015142
#
#                                                 nombre  \
# 0                 HOSPITAL SAN JUAN DE DIOS DE SEVILLA
# 1                       HOSPITAL VIRGEN DE LA VICTORIA
# 2                        HOSPITAL QUIRONSALUD MARBELLA
# 3    Centro de Diagnóstico y Tratamiento del Hospit...
# 4                HOSPITAL DE ALTA RESOLUCION DE UTRERA
# ..                                                 ...
# 178  CENTRO ASISTENCIAL HERMANAS HOSPITALARIAS DEL ...
# 179                HOSPITAL SAN CARLOS DE SAN FERNANDO
# 180                       HOSPITAL PUERTA DE ANDALUCIA
# 181           Centro de consultas externas de Marchena
# 182                         HOSPITAL INFANTA MARGARITA
#
#                              tipo sistema_sa  \
# 0                        Hospital    Privado
# 1                        Hospital    Público
# 2                        Hospital    Privado
# 3    Centro de consultas externas    Público
# 4                        Hospital    Público
# ..                            ...        ...
# 178                      Hospital    Privado
# 179                      Hospital    Público
# 180                      Hospital    Público
# 181  Centro de consultas externas    Público
# 182                      Hospital    Público
#
#                                            direccion  \
# 0                           AVENIDA EDUARDO DATO, 42
# 1                                CALLE DEMOSTENES, 8
# 2                           AVENIDA SEVERO OCHOA, 32
# 3                   AVENIDA DEL EJERCITO ESPAÑOL, 12
# 4                AVENIDA BRIGADAS INTERNACIONALES, 0
# ..                                               ...
# 178                         CALLE SAN JUAN BOSCO, 41
# 179                      PASEO CAPITAN CONFORTO, S/N
# 180                               CARRETERA J-12, 32
# 181                AVENIDA MAESTRO SANTOS RUANO, S/N
# 182  AVENIDA GONGORA, 9 - Hospital Infanta Margarita
#
#                                                    web     localidad cod_mun  \
# 0    https://web.sas.junta-andalucia.es/servicioand...       Sevilla   41091
# 1    https://web.sas.junta-andalucia.es/servicioand...        Málaga   29067
# 2    https://web.sas.junta-andalucia.es/servicioand...      Marbella   29069
# 3    https://web.sas.junta-andalucia.es/servicioand...          Jaén   23050
# 4    https://web.sas.junta-andalucia.es/servicioand...        Utrera   41095
# ..                                                 ...           ...     ...
# 178  https://web.sas.junta-andalucia.es/servicioand...        Málaga   29067
# 179  https://web.sas.junta-andalucia.es/servicioand...  San Fernando   11031
# 180  https://web.sas.junta-andalucia.es/servicioand...          Jaén   23050
# 181  https://web.sas.junta-andalucia.es/servicioand...      Marchena   41060
# 182  https://web.sas.junta-andalucia.es/servicioand...         Cabra   14013
#
#         municipio provincia                               geometry
# 0         Sevilla   Sevilla  MULTIPOINT ((237119.999 4141377.321))
# 1          Málaga    Málaga  MULTIPOINT ((368045.226 4064752.167))
# 2        Marbella    Málaga  MULTIPOINT ((332153.091 4042031.302))
# 3            Jaén      Jaén     MULTIPOINT ((430149.8 4181144.98))
# 4          Utrera   Sevilla  MULTIPOINT ((252738.481 4118059.733))
# ..            ...       ...                                    ...
# 178        Málaga    Málaga  MULTIPOINT ((373019.869 4066247.253))
# 179  San Fernando     Cádiz    MULTIPOINT ((213777.47 4041935.42))
# 180          Jaén      Jaén  MULTIPOINT ((431354.389 4183335.096))
# 181      Marchena   Sevilla   MULTIPOINT ((285478.33 4134582.987))
# 182         Cabra   Córdoba  MULTIPOINT ((373958.987 4147776.469))
#
# [183 rows x 12 columns]

# %%
# Borrrar columnas no necesarias
gdf = gdf.drop(columns=[ 'gml_id', 'id_dera', 'web', 'cod_mun',])

# %%
gdf
# Out:
#                                                 nombre  \
# 0                 HOSPITAL SAN JUAN DE DIOS DE SEVILLA
# 1                       HOSPITAL VIRGEN DE LA VICTORIA
# 2                        HOSPITAL QUIRONSALUD MARBELLA
# 3    Centro de Diagnóstico y Tratamiento del Hospit...
# 4                HOSPITAL DE ALTA RESOLUCION DE UTRERA
# ..                                                 ...
# 178  CENTRO ASISTENCIAL HERMANAS HOSPITALARIAS DEL ...
# 179                HOSPITAL SAN CARLOS DE SAN FERNANDO
# 180                       HOSPITAL PUERTA DE ANDALUCIA
# 181           Centro de consultas externas de Marchena
# 182                         HOSPITAL INFANTA MARGARITA
#
#                              tipo sistema_sa  \
# 0                        Hospital    Privado
# 1                        Hospital    Público
# 2                        Hospital    Privado
# 3    Centro de consultas externas    Público
# 4                        Hospital    Público
# ..                            ...        ...
# 178                      Hospital    Privado
# 179                      Hospital    Público
# 180                      Hospital    Público
# 181  Centro de consultas externas    Público
# 182                      Hospital    Público
#
#                                            direccion     localidad  \
# 0                           AVENIDA EDUARDO DATO, 42       Sevilla
# 1                                CALLE DEMOSTENES, 8        Málaga
# 2                           AVENIDA SEVERO OCHOA, 32      Marbella
# 3                   AVENIDA DEL EJERCITO ESPAÑOL, 12          Jaén
# 4                AVENIDA BRIGADAS INTERNACIONALES, 0        Utrera
# ..                                               ...           ...
# 178                         CALLE SAN JUAN BOSCO, 41        Málaga
# 179                      PASEO CAPITAN CONFORTO, S/N  San Fernando
# 180                               CARRETERA J-12, 32          Jaén
# 181                AVENIDA MAESTRO SANTOS RUANO, S/N      Marchena
# 182  AVENIDA GONGORA, 9 - Hospital Infanta Margarita         Cabra
#
#         municipio provincia                               geometry
# 0         Sevilla   Sevilla  MULTIPOINT ((237119.999 4141377.321))
# 1          Málaga    Málaga  MULTIPOINT ((368045.226 4064752.167))
# 2        Marbella    Málaga  MULTIPOINT ((332153.091 4042031.302))
# 3            Jaén      Jaén     MULTIPOINT ((430149.8 4181144.98))
# 4          Utrera   Sevilla  MULTIPOINT ((252738.481 4118059.733))
# ..            ...       ...                                    ...
# 178        Málaga    Málaga  MULTIPOINT ((373019.869 4066247.253))
# 179  San Fernando     Cádiz    MULTIPOINT ((213777.47 4041935.42))
# 180          Jaén      Jaén  MULTIPOINT ((431354.389 4183335.096))
# 181      Marchena   Sevilla   MULTIPOINT ((285478.33 4134582.987))
# 182         Cabra   Córdoba  MULTIPOINT ((373958.987 4147776.469))
#
# [183 rows x 8 columns]

# %%
url = "https://www.ideandalucia.es/services/DERA_g12_servicios/wfs?service=wfs&request=getcapabilities"

gdf = gpd.read_file(
    url, 
    layer='DERA_g12_servicios:g12_04_Farmacia', 
    engine="pyogrio", 
    encoding="utf-8"
)

# %%
gdf
# Out:
#                               gml_id         id_dera   nica  \
# 0     g12_04_Farmacia.11213400009499  11213400009499  40960
# 1     g12_04_Farmacia.11213400009500  11213400009500  42779
# 2     g12_04_Farmacia.11213400009501  11213400009501  41296
# 3     g12_04_Farmacia.11213400009502  11213400009502  42825
# 4     g12_04_Farmacia.11213400009503  11213400009503  42826
# ...                              ...             ...    ...
# 3869  g12_04_Farmacia.11213400013368  11213400013368  20744
# 3870  g12_04_Farmacia.11213400013369  11213400013369  23605
# 3871  g12_04_Farmacia.11213400013370  11213400013370   4928
# 3872  g12_04_Farmacia.11213400013371  11213400013371   4697
# 3873  g12_04_Farmacia.11213400013372  11213400013372  41717
#
#                                                  nombre  \
# 0             LOPEZ GAGO, ILDEFONSO.- O.FARMACIA Nº 466
# 1                FARMACIA MARTINEZ PEREZ, MARIA DOLORES
# 2               GUTIERREZ ROMAN, MANUELA O.FARMACIA 437
# 3                           CASTIILLO LOPEZ, INMACULADA
# 4                                DÍEZ RODRIGUEZ, MONICA
# ...                                                 ...
# 3869  ISABEL AMPARO DOMINGUEZ DOMINGUEZ - OF. FARMAC...
# 3870  Mª JOSE GARCIA MARQUEZ / VERONICA COLCHERO CER...
# 3871                           RODRIGUEZ SAMBLAS, NURIA
# 3872                               MERIDA GUZMAN, NURIA
# 3873                             JIMENEZ ALCALA, FATIMA
#
#                            direccion cod_mun                municipio  \
# 0               AVENIDA DIPUTACION 4   11015  Chiclana de la Frontera
# 1     AVENIDA DE LA CONSTITUCION 152   04066                    Níjar
# 2                  AVENIDA DEL MAR 9   11007                  Barbate
# 3       AVENIDA DE LAS PALMERAS 76 B   29025              Benalmádena
# 4       AVENIDA DE LA CONSTITUCION 7   29069                 Marbella
# ...                              ...     ...                      ...
# 3869         CALLE LOS CUARTELES S/N   21025                Cortegana
# 3870            CALLE VALLE FRIO S/N   21021                  Cartaya
# 3871                   CALLE PILAR 6   23037                   Génave
# 3872                   CALLE JACOB 8   29067                   Málaga
# 3873                 CALLE DEL RIO 1   29085                  Salares
#
#      provincia                               geometry
# 0        Cádiz  MULTIPOINT ((216841.878 4034864.492))
# 1      Almería  MULTIPOINT ((573773.821 4085075.644))
# 2        Cádiz  MULTIPOINT ((237597.593 4009418.347))
# 3       Málaga   MULTIPOINT ((362655.45 4050659.093))
# 4       Málaga  MULTIPOINT ((321578.134 4039524.173))
# ...        ...                                    ...
# 3869    Huelva  MULTIPOINT ((158228.905 4189354.233))
# 3870    Huelva  MULTIPOINT ((140047.224 4126173.047))
# 3871      Jaén   MULTIPOINT ((523365.566 4253562.28))
# 3872    Málaga  MULTIPOINT ((361794.504 4065906.489))
# 3873    Málaga  MULTIPOINT ((408690.025 4079160.623))
#
# [3874 rows x 9 columns]

# %%
# Borrrar columnas no necesarias
gdf = gdf.drop(columns=[ 'gml_id', 'id_dera', 'nica', 'cod_mun',])

# %%
gdf
# Out:
#                                                  nombre  \
# 0             LOPEZ GAGO, ILDEFONSO.- O.FARMACIA Nº 466
# 1                FARMACIA MARTINEZ PEREZ, MARIA DOLORES
# 2               GUTIERREZ ROMAN, MANUELA O.FARMACIA 437
# 3                           CASTIILLO LOPEZ, INMACULADA
# 4                                DÍEZ RODRIGUEZ, MONICA
# ...                                                 ...
# 3869  ISABEL AMPARO DOMINGUEZ DOMINGUEZ - OF. FARMAC...
# 3870  Mª JOSE GARCIA MARQUEZ / VERONICA COLCHERO CER...
# 3871                           RODRIGUEZ SAMBLAS, NURIA
# 3872                               MERIDA GUZMAN, NURIA
# 3873                             JIMENEZ ALCALA, FATIMA
#
#                            direccion                municipio provincia  \
# 0               AVENIDA DIPUTACION 4  Chiclana de la Frontera     Cádiz
# 1     AVENIDA DE LA CONSTITUCION 152                    Níjar   Almería
# 2                  AVENIDA DEL MAR 9                  Barbate     Cádiz
# 3       AVENIDA DE LAS PALMERAS 76 B              Benalmádena    Málaga
# 4       AVENIDA DE LA CONSTITUCION 7                 Marbella    Málaga
# ...                              ...                      ...       ...
# 3869         CALLE LOS CUARTELES S/N                Cortegana    Huelva
# 3870            CALLE VALLE FRIO S/N                  Cartaya    Huelva
# 3871                   CALLE PILAR 6                   Génave      Jaén
# 3872                   CALLE JACOB 8                   Málaga    Málaga
# 3873                 CALLE DEL RIO 1                  Salares    Málaga
#
#                                    geometry
# 0     MULTIPOINT ((216841.878 4034864.492))
# 1     MULTIPOINT ((573773.821 4085075.644))
# 2     MULTIPOINT ((237597.593 4009418.347))
# 3      MULTIPOINT ((362655.45 4050659.093))
# 4     MULTIPOINT ((321578.134 4039524.173))
# ...                                     ...
# 3869  MULTIPOINT ((158228.905 4189354.233))
# 3870  MULTIPOINT ((140047.224 4126173.047))
# 3871   MULTIPOINT ((523365.566 4253562.28))
# 3872  MULTIPOINT ((361794.504 4065906.489))
# 3873  MULTIPOINT ((408690.025 4079160.623))
#
# [3874 rows x 5 columns]

# %%
url = "https://www.ideandalucia.es/services/DERA_g7_sistema_urbano/wfs?service=wfs&request=getcapabilities"

gdf = gpd.read_file(
    url, 
    layer='DERA_g7_sistema_urbano:g07_06_ZonaVerde', 
    engine="pyogrio", 
    encoding="utf-8"
)

# %%
gdf
# Out:
#                             gml_id         id_dera    nombre    tipo  \
# 0  g07_06_ZonaVerde.10705500000001  10705500000001  Sin dato  Parque
# 1  g07_06_ZonaVerde.10705500000002  10705500000002  Sin dato  Jardín
# 2  g07_06_ZonaVerde.10705500000003  10705500000003  Sin dato  Parque
# 3  g07_06_ZonaVerde.10705500000004  10705500000004  Sin dato  Parque
# 4  g07_06_ZonaVerde.10705500000005  10705500000005  Sin dato  Parque
#
#                                             geometry
# 0  MULTIPOLYGON (((444906.196 4115298.675, 444995...
# 1  MULTIPOLYGON (((229132.476 4138664.121, 229137...
# 2  MULTIPOLYGON (((414395.535 4173214.811, 414494...
# 3  MULTIPOLYGON (((445008.359 4115219.725, 445069...
# 4  MULTIPOLYGON (((414548.827 4173232.065, 414717...

# %%
# Borrrar columnas no necesarias
gdf = gdf.drop(columns=[ 'gml_id', 'id_dera', 'nombre',])

# %%
gdf
# Out:
#                tipo                                           geometry
# 0            Parque  MULTIPOLYGON (((444906.196 4115298.675, 444995...
# 1            Jardín  MULTIPOLYGON (((229132.476 4138664.121, 229137...
# 2            Parque  MULTIPOLYGON (((414395.535 4173214.811, 414494...
# 3            Parque  MULTIPOLYGON (((445008.359 4115219.725, 445069...
# 4            Parque  MULTIPOLYGON (((414548.827 4173232.065, 414717...
# ...             ...                                                ...
# 9274         Parque  MULTIPOLYGON (((517305.832 4069616.61, 517363....
# 9275          Plaza  MULTIPOLYGON (((213075.664 4040931.035, 213102...
# 9276         Jardín  MULTIPOLYGON (((401307.45 4068603.149, 401318....
# 9277         Jardín  MULTIPOLYGON (((236545.432 4152612.1, 236561.1...
# 9278  Parque Canino  MULTIPOLYGON (((240333.571 4135917.435, 240309...
#
# [9279 rows x 2 columns]

# %%
# Borrrar columnas no necesarias
gdf = gdf.drop(columns=['id_dera', 'nombre',])

# %%
url = "https://www.ideandalucia.es/services/DERA_g7_sistema_urbano/wfs?service=wfs&request=getcapabilities"

gdf = gpd.read_file(
    url, 
    layer='DERA_g7_sistema_urbano:g07_01_Poblaciones', 
    engine="pyogrio", 
    encoding="utf-8"
)

# %%
# Borrrar columnas no necesarias
gdf = gdf.drop(columns=[ 'gml_id', 'id_dera', 'cod_sipob', 'pob_ine', 'nombre', 'nivel', 'cod_mun',])

# %%
gdf
# Out:
#                municipio provincia  \
# 0                  Albox   Almería
# 1      Santiago-Pontones      Jaén
# 2              Benizalón   Almería
# 3                  Senés   Almería
# 4                Fonelas   Granada
# ...                  ...       ...
# 57614          Turrillas   Almería
# 57615         Albuñuelas   Granada
# 57616     Arenas del Rey   Granada
# 57617          Algeciras     Cádiz
# 57618  Santiago-Pontones      Jaén
#
#                                                 geometry
# 0      MULTIPOLYGON (((580059.063 4151157.388, 580079...
# 1      MULTIPOLYGON (((542090.47 4229688.85, 542061.4...
# 2      MULTIPOLYGON (((568179.99 4116618.87, 568205.3...
# 3      MULTIPOLYGON (((559890.294 4115281.836, 559863...
# 4      MULTIPOLYGON (((483867.026 4140670.92, 483877....
# ...                                                  ...
# 57614  MULTIPOLYGON (((563243.558 4098886.188, 563279...
# 57615  MULTIPOLYGON (((444714.916 4087435.883, 444701...
# 57616  MULTIPOLYGON (((422960.965 4096765.978, 422957...
# 57617  MULTIPOLYGON (((274482.51 3993995.8, 274487.45...
# 57618  MULTIPOLYGON (((541920.758 4221401.133, 541917...
#
# [57619 rows x 3 columns]

# %%
url = "https://www.ideandalucia.es/services/DERA_g7_sistema_urbano/wfs?service=wfs&request=getcapabilities"

gdf = gpd.read_file(
    url, 
    layer='DERA_g7_sistema_urbano:g07_06_ZonaVerde', 
    engine="pyogrio", 
    encoding="utf-8"
)

# %%
gdf
# Out:
#                                gml_id         id_dera    nombre  \
# 0     g07_06_ZonaVerde.10705500000001  10705500000001  Sin dato
# 1     g07_06_ZonaVerde.10705500000002  10705500000002  Sin dato
# 2     g07_06_ZonaVerde.10705500000003  10705500000003  Sin dato
# 3     g07_06_ZonaVerde.10705500000004  10705500000004  Sin dato
# 4     g07_06_ZonaVerde.10705500000005  10705500000005  Sin dato
# ...                               ...             ...       ...
# 9274  g07_06_ZonaVerde.10705500009275  10705500009275  Sin dato
# 9275  g07_06_ZonaVerde.10705500009276  10705500009276  Sin dato
# 9276  g07_06_ZonaVerde.10705500009277  10705500009277  Sin dato
# 9277  g07_06_ZonaVerde.10705500009278  10705500009278  Sin dato
# 9278  g07_06_ZonaVerde.10705500009279  10705500009279  Sin dato
#
#                tipo                                           geometry
# 0            Parque  MULTIPOLYGON (((444906.196 4115298.675, 444995...
# 1            Jardín  MULTIPOLYGON (((229132.476 4138664.121, 229137...
# 2            Parque  MULTIPOLYGON (((414395.535 4173214.811, 414494...
# 3            Parque  MULTIPOLYGON (((445008.359 4115219.725, 445069...
# 4            Parque  MULTIPOLYGON (((414548.827 4173232.065, 414717...
# ...             ...                                                ...
# 9274         Parque  MULTIPOLYGON (((517305.832 4069616.61, 517363....
# 9275          Plaza  MULTIPOLYGON (((213075.664 4040931.035, 213102...
# 9276         Jardín  MULTIPOLYGON (((401307.45 4068603.149, 401318....
# 9277         Jardín  MULTIPOLYGON (((236545.432 4152612.1, 236561.1...
# 9278  Parque Canino  MULTIPOLYGON (((240333.571 4135917.435, 240309...
#
# [9279 rows x 5 columns]

# %%
# Borrrar columnas no necesarias
gdf = gdf.drop(columns=[ 'gml_id', 'id_dera', 'nombre',])

# %%
gdf
# Out:
#                tipo                                           geometry
# 0            Parque  MULTIPOLYGON (((444906.196 4115298.675, 444995...
# 1            Jardín  MULTIPOLYGON (((229132.476 4138664.121, 229137...
# 2            Parque  MULTIPOLYGON (((414395.535 4173214.811, 414494...
# 3            Parque  MULTIPOLYGON (((445008.359 4115219.725, 445069...
# 4            Parque  MULTIPOLYGON (((414548.827 4173232.065, 414717...
# ...             ...                                                ...
# 9274         Parque  MULTIPOLYGON (((517305.832 4069616.61, 517363....
# 9275          Plaza  MULTIPOLYGON (((213075.664 4040931.035, 213102...
# 9276         Jardín  MULTIPOLYGON (((401307.45 4068603.149, 401318....
# 9277         Jardín  MULTIPOLYGON (((236545.432 4152612.1, 236561.1...
# 9278  Parque Canino  MULTIPOLYGON (((240333.571 4135917.435, 240309...
#
# [9279 rows x 2 columns]
