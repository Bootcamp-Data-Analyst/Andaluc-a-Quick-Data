# %%
# Importar libreria Geopandas
import geopandas as gpd

# %%
# Lectura de archivo
gdf = gpd.read_file("Datos/Centros_Salud.shp", engine="pyogrio")

# %%
gdf
# Out:
#            id_dera                            nombre  \
# 0     1.121310e+13                     Los Pascuales
# 1     1.121310e+13                        Benamaurel
# 2     1.121310e+13                     El Alcornocal
# 3     1.121310e+13                          El Molar
# 4     1.121310e+13                     Almayate Alto
# ...            ...                               ...
# 1511  1.121310e+13                           Nechite
# 1512  1.121310e+13  San Sebastián de los Ballesteros
# 1513  1.121310e+13                          Zagrilla
# 1514  1.121310e+13                          Terreros
# 1515  1.121310e+13     Baena Dr. Ignacio Osuna Gómez
#
#                                       direccion   telefono  \
# 0               TRAVESIA AVENIDA PUERTA (LA), 0  953439008
# 1                 CALLE CALDERON DE LA BARCA, 0  958869608
# 2                CALLE CASTELAR (ALCORNOCAL), 5  600165925
# 3                    AVENIDA ANDALUCIA (DE), 12  953105134
# ...

# %%
# Borrrar columnas no necesarias
gdf = gdf.drop(columns=['id_dera', 'nombre', 'direccion', 'telefono', 'web', 'localidad', 'cod_mun', 'geometry'])

# %%
gdf
# Out:
#                              municipio provincia
# 0                  La Puerta de Segura      Jaén
# 1                           Benamaurel   Granada
# 2                       Fuente Obejuna   Córdoba
# 3                              Cazorla      Jaén
# 4                         Vélez-Málaga    Málaga
# ...                                ...       ...
# 1511                             Válor   Granada
# 1512  San Sebastián de los Ballesteros   Córdoba
# 1513                 Priego de Córdoba   Córdoba
# 1514                             Pulpí   Almería
# 1515                             Baena   Córdoba
#
# [1516 rows x 2 columns]

# %%
gdf = gpd.read_file("Datos/Hospitales.shp", engine="pyogrio")

# %%
gdf
# Out:
#           id_dera                                             nombre  \
# 0    1.121320e+13               HOSPITAL SAN JUAN DE DIOS DE SEVILLA
# 1    1.121320e+13                     HOSPITAL VIRGEN DE LA VICTORIA
# 2    1.121320e+13                      HOSPITAL QUIRONSALUD MARBELLA
# 3    1.121320e+13  Centro de Diagnóstico y Tratamiento del Hospit...
# 4    1.121320e+13              HOSPITAL DE ALTA RESOLUCION DE UTRERA
# ..            ...                                                ...
# 178  1.121320e+13  CENTRO ASISTENCIAL HERMANAS HOSPITALARIAS DEL ...
# 179  1.121320e+13                HOSPITAL SAN CARLOS DE SAN FERNANDO
# 180  1.121320e+13                       HOSPITAL PUERTA DE ANDALUCIA
# 181  1.121320e+13           Centro de consultas externas de Marchena
# 182  1.121320e+13                         HOSPITAL INFANTA MARGARITA
#
#                              tipo sistema_sa  \
# 0                        Hospital    Privado
# ...

# %%
# Borrrar columnas no necesarias
gdf = gdf.drop(columns=['id_dera', 'web', 'cod_mun', 'geometry'])

# %%
gdf
# Out:
#                                                 nombre  \
# 0                 HOSPITAL SAN JUAN DE DIOS DE SEVILLA
# 1                       HOSPITAL VIRGEN DE LA VICTORIA
# 2                        HOSPITAL QUIRONSALUD MARBELLA
# 3    Centro de Diagnóstico y Tratamiento del Hospit...
# 4                HOSPITAL DE ALTA RESOLUCION DE UTRERA
# ..                                                 ...
# 178  CENTRO ASISTENCIAL HERMANAS HOSPITALARIAS DEL ...
# 179                HOSPITAL SAN CARLOS DE SAN FERNANDO
# 180                       HOSPITAL PUERTA DE ANDALUCIA
# 181           Centro de consultas externas de Marchena
# 182                         HOSPITAL INFANTA MARGARITA
#
#                              tipo sistema_sa  \
# 0                        Hospital    Privado
# 1                        Hospital    Público
# 2                        Hospital    Privado
# 3    Centro de consultas externas    Público
# 4                        Hospital    Público
# ...

# %%
gdf = gpd.read_file("Datos/Parques.shp", engine="pyogrio")

# %%
gdf
# Out:
#            id_dera    nombre           tipo  \
# 0     1.070550e+13  Sin dato         Parque
# 1     1.070550e+13  Sin dato         Jardín
# 2     1.070550e+13  Sin dato         Parque
# 3     1.070550e+13  Sin dato         Parque
# 4     1.070550e+13  Sin dato         Parque
# ...            ...       ...            ...
# 9274  1.070550e+13  Sin dato         Parque
# 9275  1.070550e+13  Sin dato          Plaza
# 9276  1.070550e+13  Sin dato         Jardín
# 9277  1.070550e+13  Sin dato         Jardín
# 9278  1.070550e+13  Sin dato  Parque Canino
#
#                                                geometry
# 0     POLYGON ((444906.196 4115298.675, 444995.117 4...
# 1     POLYGON ((229132.476 4138664.121, 229137.515 4...
# 2     POLYGON ((414395.535 4173214.811, 414494.871 4...
# 3     POLYGON ((445008.359 4115219.725, 445069.088 4...
# 4     POLYGON ((414548.827 4173232.065, 414717.638 4...
# ...                                                 ...
# ...

# %%
# Borrrar columnas no necesarias
gdf = gdf.drop(columns=['id_dera', 'nombre', 'geometry'])

# %%
gdf
# Out:
#                tipo
# 0            Parque
# 1            Jardín
# 2            Parque
# 3            Parque
# 4            Parque
# ...             ...
# 9274         Parque
# 9275          Plaza
# 9276         Jardín
# 9277         Jardín
# 9278  Parque Canino
#
# [9279 rows x 1 columns]

# %%
gdf = gpd.read_file("Datos/Poblacion.shp", engine="pyogrio")

# %%
gdf
# Out:
#             id_dera        cod_sipob pob_ine                         nombre  \
# 0      1.072400e+13  040060004990012      No            Cortijos de Esteban
# 1      1.072400e+13  239040025990005      No     Cortijos de Parralejo Bajo
# 2      1.072400e+13  040270001990004      No  Cortijos de los Pinchos Bajos
# 3      1.072400e+13  040820002990036      No       Cortijos de los Zarzales
# 4      1.072400e+13  180760001990043      No                       Depósito
# ...             ...              ...     ...                            ...
# 57614  1.072400e+13  040940005990007      No          Cortijos de José Meca
# 57615  1.072400e+13  180070002990004      No                       Depósito
# 57616  1.072400e+13  180200004010008      No             Cortjo del Pajonal
# 57617  1.072400e+13  110040003990009      No            Cortijos de la Joya
# 57618  1.072400e+13  239040035990004      No    Cortijos de las Fontanillas
#
# ...

# %%
# Borrrar columnas no necesarias
gdf = gdf.drop(columns=['id_dera', 'cod_sipob', 'pob_ine', 'nombre', 'nivel', 'cod_mun', 'geometry'])

# %%
gdf
# Out:
#                municipio provincia
# 0                  Albox   Almería
# 1      Santiago-Pontones      Jaén
# 2              Benizalón   Almería
# 3                  Senés   Almería
# 4                Fonelas   Granada
# ...                  ...       ...
# 57614          Turrillas   Almería
# 57615         Albuñuelas   Granada
# 57616     Arenas del Rey   Granada
# 57617          Algeciras     Cádiz
# 57618  Santiago-Pontones      Jaén
#
# [57619 rows x 2 columns]

# %%
gdf = gpd.read_file("Datos/Zonas_Verdes.shp", engine="pyogrio")

# %%
gdf
# Out:
#            id_dera    nombre           tipo  \
# 0     1.070550e+13  Sin dato         Parque
# 1     1.070550e+13  Sin dato         Jardín
# 2     1.070550e+13  Sin dato         Parque
# 3     1.070550e+13  Sin dato         Parque
# 4     1.070550e+13  Sin dato         Parque
# ...            ...       ...            ...
# 9274  1.070550e+13  Sin dato         Parque
# 9275  1.070550e+13  Sin dato          Plaza
# 9276  1.070550e+13  Sin dato         Jardín
# 9277  1.070550e+13  Sin dato         Jardín
# 9278  1.070550e+13  Sin dato  Parque Canino
#
#                                                geometry
# 0     POLYGON ((444906.196 4115298.675, 444995.117 4...
# 1     POLYGON ((229132.476 4138664.121, 229137.515 4...
# 2     POLYGON ((414395.535 4173214.811, 414494.871 4...
# 3     POLYGON ((445008.359 4115219.725, 445069.088 4...
# 4     POLYGON ((414548.827 4173232.065, 414717.638 4...
# ...                                                 ...
# ...

# %%
# Borrrar columnas no necesarias
gdf = gdf.drop(columns=['id_dera', 'nombre', 'geometry'])

# %%
gdf
# Out:
#                tipo
# 0            Parque
# 1            Jardín
# 2            Parque
# 3            Parque
# 4            Parque
# ...             ...
# 9274         Parque
# 9275          Plaza
# 9276         Jardín
# 9277         Jardín
# 9278  Parque Canino
#
# [9279 rows x 1 columns]
